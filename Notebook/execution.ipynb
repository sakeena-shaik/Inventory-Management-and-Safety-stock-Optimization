# %%
from Automation import *

# %%
def run_pipeline():
    file_path="C:/Users/SAKEENA/Downloads/data Analytics/inventory data.csv"
    df=load_and_clean(file_path)
    save_data(df)
if __name__=="__main__":
    run_pipeline()
